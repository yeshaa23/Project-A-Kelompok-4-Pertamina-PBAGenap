# %%
from google.colab import drive
drive.mount('/content/drive')

# Path to your file in Google Drive
file_path = '/content/drive/MyDrive/artikel_manual_pertamina.csv'

import pandas as pd
df = pd.read_csv(file_path)
df.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#    Case ID  Case    Newsroom           Tanggal  \
# 0      NaN   NaN  ylki.or.id      June 8, 2016
# 1      NaN   NaN  Kompas.com       6 Juli 2017
# 2      NaN   NaN  Kompas.com  14 Desember 2017
# 3      NaN   NaN  Kompas.com      27 Juli 2017
# 4      NaN   NaN  Kompas.com     18 Maret 2026
#
#                                                Judul  \
# 0  Siaran Pers YLKI : Mendesak PT Pertamina untuk...
# 1  Pertamina Kembangkan Program Non-Tunai Pembeli...
# 2   Pertamina Tak Masalahkan Nama Pertamini, tapi...
# 3  Pertamina Patra Niaga Akan Bangun SPBU Skala U...
# 4  Gaji Manajer 'Engineering' Chevron Rp 51,25 Ju...
#
#                                               Konten  \
# 0  Kejadian kecurangan takaran pada SPBU yang ter...
# 1  PONTIANAK, KOMPAS.com - PT Pertamina mensosial...
# 2  Nusa Dua, KompasOtomotif - Keberadaan kios-kio...
# 3  JAKARTA, KOMPAS.com - PT Pertamina Patra Niaga...
# 4  JAKARTA, KOMPAS.com - Situs pencari kerja, Job...
#
#                                                 Link     Tag     Tone
# 0  https://ylki.or.id/siaran-pers-ylki-mendesak-p...   Hukum  Negatif
# 1  https://money.kompas.com/read/2017/07/06/14535...     BBM   Netral
# 2  https://otomotif.kompas.com/read/2017/12/14/15...  Bisnis  Positif
# 3  https://money.kompas.com/read/2017/07/27/17565...  Bisnis  Positif
# 4  https://money.kompas.com/read/2016/03/18/14152...  Bisnis  Negatif

# %%
import pandas as pd

# Preview dataset
print("Dataset Shape:", df.shape)
df.head()

# Next Module: **3. Preprocessing Text Data**
# Out:
# Dataset Shape: (50, 9)
#    Case ID  Case    Newsroom           Tanggal  \
# 0      NaN   NaN  ylki.or.id      June 8, 2016
# 1      NaN   NaN  Kompas.com       6 Juli 2017
# 2      NaN   NaN  Kompas.com  14 Desember 2017
# 3      NaN   NaN  Kompas.com      27 Juli 2017
# 4      NaN   NaN  Kompas.com     18 Maret 2026
#
#                                                Judul  \
# 0  Siaran Pers YLKI : Mendesak PT Pertamina untuk...
# 1  Pertamina Kembangkan Program Non-Tunai Pembeli...
# 2   Pertamina Tak Masalahkan Nama Pertamini, tapi...
# 3  Pertamina Patra Niaga Akan Bangun SPBU Skala U...
# 4  Gaji Manajer 'Engineering' Chevron Rp 51,25 Ju...
#
#                                               Konten  \
# 0  Kejadian kecurangan takaran pada SPBU yang ter...
# 1  PONTIANAK, KOMPAS.com - PT Pertamina mensosial...
# 2  Nusa Dua, KompasOtomotif - Keberadaan kios-kio...
# 3  JAKARTA, KOMPAS.com - PT Pertamina Patra Niaga...
# 4  JAKARTA, KOMPAS.com - Situs pencari kerja, Job...
#
#                                                 Link     Tag     Tone
# 0  https://ylki.or.id/siaran-pers-ylki-mendesak-p...   Hukum  Negatif
# 1  https://money.kompas.com/read/2017/07/06/14535...     BBM   Netral
# 2  https://otomotif.kompas.com/read/2017/12/14/15...  Bisnis  Positif
# 3  https://money.kompas.com/read/2017/07/27/17565...  Bisnis  Positif
# 4  https://money.kompas.com/read/2016/03/18/14152...  Bisnis  Negatif

# %%
### 🔧 Implementation
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

nltk.download('punkt')
nltk.download('stopwords')
nltk.download('punkt_tab')


# Example: use only first article for demonstration
text = df['Konten'][0]


# Lowercase
text = text.lower()


# Remove punctuation & numbers
text = re.sub(r'[^a-zA-Z\s]', '', text)


# Tokenization
tokens = word_tokenize(text)


# Remove stopwords
stop_words = set(stopwords.words('indonesian'))
filtered_tokens = [w for w in tokens if w not in stop_words]


print("Original Text (shortened):", df['Konten'][0][:300])
print("\nProcessed Tokens:", filtered_tokens[:30])
# Out:
# Original Text (shortened): Kejadian kecurangan takaran pada SPBU yang terjadi di Rempoa, Ciputat, sesungguhnya bukan hal yang baru, banyak modus operandi yang dilakukan pengelola SPBU yang mengakibatkan kerugian konsumen. Sejak February 2016 YLKI telah mendapatkan informasi dari Direktur Jenderal Perlindungan Konsumen bahwa b
#
# Processed Tokens: ['kejadian', 'kecurangan', 'takaran', 'spbu', 'rempoa', 'ciputat', 'sesungguhnya', 'modus', 'operandi', 'pengelola', 'spbu', 'mengakibatkan', 'kerugian', 'konsumen', 'february', 'ylki', 'informasi', 'direktur', 'jenderal', 'perlindungan', 'konsumen', 'berdasarkan', 'pantauan', 'bph', 'migas', 'spbu', 'wilayah', 'sumatera', 'yg', 'kecurangan']
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
import pandas as pd
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

nltk.download('punkt')
nltk.download('stopwords')

# Example: Apply TF-IDF on the 'Content' column of your dataset
# (replace 'Content' with your actual column name if different)
documents = df['Konten'].astype(str).tolist()

# Get Indonesian stopwords
stop_words = set(stopwords.words('indonesian'))

# Initialize TF-IDF Vectorizer
vectorizer = TfidfVectorizer(max_features=20, ngram_range=(1,2), stop_words=list(stop_words))
tfidf_matrix = vectorizer.fit_transform(documents)

# Get feature names and scores
feature_names = vectorizer.get_feature_names_out()
dense = tfidf_matrix.todense()
denselist = dense.tolist()

# Create a DataFrame of TF-IDF scores
tfidf_df = pd.DataFrame(denselist, columns=feature_names)

print("Top TF-IDF Features across all documents:")
print(tfidf_df.sum().sort_values(ascending=False).head(20))
# Out:
# Top TF-IDF Features across all documents:
# pertamina       17.087924
# bbm              7.744950
# energi           6.864225
# spbu             6.015119
# rp               5.756765
# tangki           5.746533
# program          5.206254
# jakarta          4.532699
# pt               4.464275
# minyak           4.401319
# perusahaan       4.400513
# indonesia        4.114974
# direktur         4.083759
# nasional         3.918007
# pt pertamina     3.773427
# harga            3.552753
# kapal            3.423433
# masyarakat       3.390687
# liter            3.294414
# lingkungan       3.185545
# dtype: float64
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from nltk.corpus import stopwords # Import stopwords

# Take the 'content' column for analysis
texts = df['Konten'].dropna().tolist()

# Get Indonesian stopwords
stop_words = set(stopwords.words('indonesian'))

# Create CountVectorizer for bigrams & trigrams
vectorizer = CountVectorizer(ngram_range=(2,3), stop_words=list(stop_words), max_features=10)
X = vectorizer.fit_transform(texts)

# Get top bigrams/trigrams
ngrams = vectorizer.get_feature_names_out()
counts = X.sum(axis=0).A1
ngram_freq = pd.DataFrame({'ngram': ngrams, 'count': counts}).sort_values(by='count', ascending=False)

ngram_freq
# Out:
#                    ngram  count
# 8           pt pertamina     71
# 7      pertamina persero     44
# 9   pt pertamina persero     43
# 0            bahan bakar     32
# 3           mobil tangki     30
# 4            patra niaga     23
# 6  pertamina patra niaga     23
# 5        pertamina patra     23
# 1         direktur utama     21
# 2        energi nasional     20

# %% [markdown]
# ## 5. Keyword Extraction
#
# Now that we have preprocessed the text, we can explore different keyword extraction techniques to identify the most important terms in the articles.
#
# ### 5.1 TF-IDF (Term Frequency-Inverse Document Frequency)
#
# We have already calculated the TF-IDF scores. We can use these scores to identify important keywords for each document or across the entire corpus.
#
# ### 5.2 TextRank
#
# TextRank is a graph-based algorithm that can be used for keyword extraction. It is based on the idea that important words are those that are related to many other important words in the text.
#
# ### 5.3 RAKE (Rapid Automatic Keyword Extraction)
#
# RAKE is another algorithm for keyword extraction that identifies keywords based on the frequency of words and the distance between them.

# %%
# Example: Extract keywords for the first document using TF-IDF
document_index = 0
tfidf_scores = tfidf_df.iloc[document_index]
sorted_keywords = tfidf_scores.sort_values(ascending=False)

print(f"Top TF-IDF keywords for document {document_index + 1}:")
print(sorted_keywords.head(10))
# Out:
# Top TF-IDF keywords for document 1:
# spbu            0.930489
# pt pertamina    0.214143
# pt              0.209924
# pertamina       0.179326
# direktur        0.110033
# harga           0.000000
# bbm             0.000000
# energi          0.000000
# indonesia       0.000000
# jakarta         0.000000
# Name: 0, dtype: float64

# %% [markdown]
# ## 6. Text Embeddings
#
# Text embeddings are numerical representations of text that capture semantic meaning. We can use embeddings to analyze the similarity between documents or words.
#
# ### 6.1 Word Embeddings (e.g., Word2Vec, GloVe)
#
# Word embeddings represent individual words as vectors.
#
# ### 6.2 Document Embeddings (e.g., Doc2Vec, Sentence-BERT)
#
# Document embeddings represent entire documents as vectors.
#
# ### 6.3 Using Pre-trained Embeddings
#
# We can use pre-trained embeddings to leverage knowledge from large datasets.

# %%
# Example: Placeholder for TextRank and RAKE implementation
print("Implementing TextRank and RAKE in the next steps...")
# Out:
# Implementing TextRank and RAKE in the next steps...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
import pandas as pd
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

nltk.download('punkt')
nltk.download('stopwords')

# Example: Apply TF-IDF on the 'Content' column of your dataset
# (replace 'Content' with your actual column name if different)
documents = df['Konten'].astype(str).tolist()

# Get Indonesian stopwords
stop_words = set(stopwords.words('indonesian'))

# Initialize TF-IDF Vectorizer
vectorizer = TfidfVectorizer(max_features=20, ngram_range=(1,2), stop_words=list(stop_words))
tfidf_matrix = vectorizer.fit_transform(documents)

# Get feature names and scores
feature_names = vectorizer.get_feature_names_out()
dense = tfidf_matrix.todense()
denselist = dense.tolist()

# Create a DataFrame of TF-IDF scores
import pandas as pd
tfidf_df = pd.DataFrame(denselist, columns=feature_names)

print("Top TF-IDF Features across all documents:")
print(tfidf_df.sum().sort_values(ascending=False).head(20))
# Out:
# Top TF-IDF Features across all documents:
# pertamina       17.087924
# bbm              7.744950
# energi           6.864225
# spbu             6.015119
# rp               5.756765
# tangki           5.746533
# program          5.206254
# jakarta          4.532699
# pt               4.464275
# minyak           4.401319
# perusahaan       4.400513
# indonesia        4.114974
# direktur         4.083759
# nasional         3.918007
# pt pertamina     3.773427
# harga            3.552753
# kapal            3.423433
# masyarakat       3.390687
# liter            3.294414
# lingkungan       3.185545
# dtype: float64
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import os
import warnings

# Menyembunyikan pesan peringatan agar output di GitHub bersih
warnings.filterwarnings("ignore")

import re
import pandas as pd
import nltk
from collections import Counter

# Download modul NLTK secara diam-diam (tanpa progress bar)
nltk.download("punkt", quiet=True)

# Define lemma roots (Konteks Pertamina)
lemmas = ["curang", "timbun", "subsidi", "sanksi"]

# Regex patterns to catch variations of each lemma
patterns = {lemma: re.compile(rf"\b\w*{lemma}\w*\b", re.IGNORECASE) for lemma in lemmas}

# Function: extract sentences + matched variations
def find_variations(text, patterns):
    if pd.isna(text):
        return []
    found = []
    sentences = nltk.sent_tokenize(text)
    for sent in sentences:
        for lemma, pattern in patterns.items():
            matches = pattern.findall(sent)
            if matches:
                found.append((lemma, sent.strip(), matches))
    return found

# Apply to dataset
df['lemma_sentences'] = df['Konten'].apply(lambda x: find_variations(x, patterns))

# Flatten results for frequency summary
all_matches = []
for row in df['lemma_sentences']:
    for lemma, sent, matches in row:
        all_matches.extend([(lemma, m.lower()) for m in matches])

# Count frequency per lemma root
lemma_counts = Counter([lemma for lemma, _ in all_matches])

# Count frequency per variation
variation_counts = Counter([match for _, match in all_matches])

# Convert to DataFrames for readability
df_lemma_summary = pd.DataFrame(lemma_counts.items(), columns=["lemma_root", "count"]).sort_values(by="count", ascending=False)
df_variation_summary = pd.DataFrame(variation_counts.items(), columns=["variation", "count"]).sort_values(by="count", ascending=False)

print("🔹 Frequency per Lemma Root:")
display(df_lemma_summary)

print("🔹 Frequency per Word Variation:")
display(df_variation_summary)

# Show sentences with matches (sample 5)
df_lemma_sentences = df[df['lemma_sentences'].str.len() > 0][['Judul', 'lemma_sentences']]
display(df_lemma_sentences.head(5))
# Out:
# 🔹 Frequency per Lemma Root:
#   lemma_root  count
# 2    subsidi     24
# 0     curang      5
# 1     sanksi      1
# 3     timbun      1
# 🔹 Frequency per Word Variation:
#       variation  count
# 3       subsidi     19
# 0    kecurangan      4
# 7    nonsubsidi      2
# 2        sanksi      1
# 1        curang      1
# 4        timbun      1
# 5     disubsidi      1
# 6  subsiditepat      1
# 8    bersubsidi      1
#                                                 Judul  \
# 0   Siaran Pers YLKI : Mendesak PT Pertamina untuk...
# 3   Pertamina Patra Niaga Akan Bangun SPBU Skala U...
# 6          Pertamina Jamin Stok BBM Jelang Mudik 2017
# 11  Sambut Arus Mudik 2026, Komut Pertamina Tinjau...
# 13  Pertamina Naikkan Harga BBM per 1 Maret, Perta...
#
#                                       lemma_sentences
# 0   [(curang, Kejadian kecurangan takaran pada SPB...
# 3   [(subsidi, Ditargetkan, tahun ini SPBU UKM ber...
# 6   [(subsidi, Hal ini berlaku untuk semua jenis B...
# 11  [(timbun, Tak hanya memantau aspek teknis sepe...
# 13  [(subsidi, Harga pertamax green yang 1 Februar...

# %%
import re
import pandas as pd
import nltk
from collections import Counter

nltk.download("punkt")

# Define lemma roots
lemmas = ["curang", "timbun", "subsidi", "sanksi"]

# Regex patterns to catch variations of each lemma
patterns = {lemma: re.compile(rf"\b\w*{lemma}\w*\b", re.IGNORECASE) for lemma in lemmas}

# Function: extract sentences + matched variations
def find_variations(text, patterns):
    if pd.isna(text):
        return []
    found = []
    sentences = nltk.sent_tokenize(text)
    for sent in sentences:
        for lemma, pattern in patterns.items():
            matches = pattern.findall(sent)
            if matches:
                found.append((lemma, sent.strip(), matches))
    return found

# Apply to dataset
df['lemma_sentences'] = df['Konten'].apply(lambda x: find_variations(x, patterns))

# --- 1) Lemma frequency summary ---
all_matches = []
for row in df['lemma_sentences']:
    for lemma, sent, matches in row:
        all_matches.extend([(lemma, m.lower()) for m in matches])

lemma_counts = Counter([lemma for lemma, _ in all_matches])
df_lemma_summary = pd.DataFrame(
    lemma_counts.items(), columns=["lemma_root", "count"]
).sort_values(by="count", ascending=False)

# --- 2) Variation frequency summary ---
variation_counts = Counter([match for _, match in all_matches])
df_variation_summary = pd.DataFrame(
    variation_counts.items(), columns=["variation", "count"]
).sort_values(by="count", ascending=False)

# --- 3) Sentence-level matches ---
rows = []
for i, row in df.iterrows():
    for lemma, sent, matches in row['lemma_sentences']:
        for m in matches:
            rows.append({
                "Judul": row['Judul'],
                "lemma_root": lemma,
                "match": m,
                "sentence": sent
            })

df_sentence_matches = pd.DataFrame(rows)


# df_lemma_summary
# df_variation_summary
# df_sentence_matches
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
df_lemma_summary
# Out:
#   lemma_root  count
# 2    subsidi     24
# 0     curang      5
# 1     sanksi      1
# 3     timbun      1

# %%
df_variation_summary
# Out:
#       variation  count
# 3       subsidi     19
# 0    kecurangan      4
# 7    nonsubsidi      2
# 2        sanksi      1
# 1        curang      1
# 4        timbun      1
# 5     disubsidi      1
# 6  subsiditepat      1
# 8    bersubsidi      1

# %%
df_sentence_matches
# Out:
#                                                 Judul lemma_root  \
# 0   Siaran Pers YLKI : Mendesak PT Pertamina untuk...     curang
# 1   Siaran Pers YLKI : Mendesak PT Pertamina untuk...     curang
# 2   Siaran Pers YLKI : Mendesak PT Pertamina untuk...     curang
# 3   Siaran Pers YLKI : Mendesak PT Pertamina untuk...     curang
# 4   Siaran Pers YLKI : Mendesak PT Pertamina untuk...     sanksi
# 5   Siaran Pers YLKI : Mendesak PT Pertamina untuk...     curang
# 6   Pertamina Patra Niaga Akan Bangun SPBU Skala U...    subsidi
# 7   Pertamina Patra Niaga Akan Bangun SPBU Skala U...    subsidi
# 8          Pertamina Jamin Stok BBM Jelang Mudik 2017    subsidi
# 9          Pertamina Jamin Stok BBM Jelang Mudik 2017    subsidi
# 10  Sambut Arus Mudik 2026, Komut Pertamina Tinjau...     timbun
# 11  Pertamina Naikkan Harga BBM per 1 Maret, Perta...    subsidi
# 12  Pertamina: MyPertamina untuk Lindungi Konsumen...    subsidi
# 13  Pertamina: MyPertamina untuk Lindungi Konsumen...    subsidi
# 14  Pertamina: MyPertamina untuk Lindungi Konsumen...    subsidi
# 15  Pertamina: MyPertamina untuk Lindungi Konsumen...    subsidi
# 16  Pertamina: MyPertamina untuk Lindungi Konsumen...    subsidi
# 17  Pertamina: MyPertamina untuk Lindungi Konsumen...    subsidi
# 18  Pertamina: MyPertamina untuk Lindungi Konsumen...    subsidi
# 19  Pertamina: MyPertamina untuk Lindungi Konsumen...    subsidi
# 20  Pertamina: MyPertamina untuk Lindungi Konsumen...    subsidi
# 21  Pertamina Naikkan Harga Pertamax Cs, Pertamina...    subsidi
# 22  Pertamina Naikkan Harga Pertamax Cs, Pertamina...    subsidi
# 23  Pertamina Naikkan Harga Pertamax Cs, Pertamina...    subsidi
# 24  Pandemi, Penjualan BBM Pertamina 2020 Turun 24,5%    subsidi
# 25  Harga LPG Non Subsidi Naik Jadi Rp 11.500 per ...    subsidi
# 26  Harga LPG Non Subsidi Naik Jadi Rp 11.500 per ...    subsidi
# 27  Harga LPG Non Subsidi Naik Jadi Rp 11.500 per ...    subsidi
# 28  Harga LPG Non Subsidi Naik Jadi Rp 11.500 per ...    subsidi
# 29  Harga LPG Non Subsidi Naik Jadi Rp 11.500 per ...    subsidi
# 30  Harga LPG Non Subsidi Naik Jadi Rp 11.500 per ...    subsidi
#
#            match                                           sentence
# 0     kecurangan  Kejadian kecurangan takaran pada SPBU yang ter...
# 1     kecurangan  Sejak February 2016 YLKI telah mendapatkan inf...
# 2     kecurangan  PERTAMINA (Persero) segera melakukan pengawasa...
# 3         curang  Agar PT Pertamina memberikan sanksi tegas pada...
# 4         sanksi  Agar PT Pertamina memberikan sanksi tegas pada...
# 5     kecurangan  Selama ini kasus kecurangan SPBU hanya berhent...
# 6        subsidi  Ditargetkan, tahun ini SPBU UKM berkapasitas 5...
# 7        subsidi  "Jenis BBM medium, Pertalite, Dexlite, non sub...
# 8        subsidi  Hal ini berlaku untuk semua jenis BBM, baik su...
# 9        subsidi  Hal ini berlaku untuk semua jenis BBM, baik su...
# 10        timbun  Tak hanya memantau aspek teknis seperti tangki...
# 11       subsidi  Harga pertamax green yang 1 Februari lalu dipa...
# 12       subsidi  Menurut dia, dengan mendaftar di MyPertamina a...
# 13       subsidi  “Pendaftaran ini ditujukan agar penyaluran BBM...
# 14       subsidi  Diberitakan sebelumnya, kuota BBM subsidi saat...
# 15       subsidi  Pertamina mencatat sampai dengan bulan Juli 20...
# 16       subsidi  Sementara itu, BBM subsidi jenis Pertalite, su...
# 17     disubsidi  “Untuk memastikan BBM yang disubsidi oleh Peme...
# 18       Subsidi  “Untuk memastikan BBM yang disubsidi oleh Peme...
# 19  subsiditepat  “Untuk memastikan BBM yang disubsidi oleh Peme...
# 20       Subsidi  Ia menjelaskan, pihaknya juga telah membuka bo...
# 21    nonsubsidi  JAKARTA, KOMPAS.com – PT Pertamina (Persero) k...
# 22    nonsubsidi  Terpantau semua harga BBM nonsubsidi Pertamina...
# 23    bersubsidi  Selain itu, BBM bersubsidi pada bulan ini terp...
# 24       subsidi  Adapun penggantian biaya subsidi dari pemerint...
# 25       subsidi  JAKARTA – PT Pertamina (Persero) mengklaim har...
# 26       subsidi  Untuk Malaysia dan Thailand harga LPG relatif ...
# 27       subsidi  Irto menjelaskan Pertamina menyesuaikan harga ...
# 28       subsidi  Menurutnya penyesuaian harga LPG non subsidi t...
# 29       subsidi  Besaran penyesuaian harga LPG non subsidi yang...
# 30       subsidi  Irto memastikan LPG subsidi 3 Kg yang secara k...

# %%
df_sentence_matches.head()
# Out:
#                                                Judul lemma_root       match  \
# 0  Siaran Pers YLKI : Mendesak PT Pertamina untuk...     curang  kecurangan
# 1  Siaran Pers YLKI : Mendesak PT Pertamina untuk...     curang  kecurangan
# 2  Siaran Pers YLKI : Mendesak PT Pertamina untuk...     curang  kecurangan
# 3  Siaran Pers YLKI : Mendesak PT Pertamina untuk...     curang      curang
# 4  Siaran Pers YLKI : Mendesak PT Pertamina untuk...     sanksi      sanksi
#
#                                             sentence
# 0  Kejadian kecurangan takaran pada SPBU yang ter...
# 1  Sejak February 2016 YLKI telah mendapatkan inf...
# 2  PERTAMINA (Persero) segera melakukan pengawasa...
# 3  Agar PT Pertamina memberikan sanksi tegas pada...
# 4  Agar PT Pertamina memberikan sanksi tegas pada...

# %%
# Explode matches into flat table
rows = []
for i, row in df.iterrows():
    for lemma, sent, matches in row['lemma_sentences']:
        for m in matches:
            rows.append({
                "Judul": row['Judul'],
                "lemma_root": lemma,
                "match": m,
                "sentence": sent
            })

df_matches = pd.DataFrame(rows)
display(df_matches.head(10))
# Out:
#                                                Judul lemma_root       match  \
# 0  Siaran Pers YLKI : Mendesak PT Pertamina untuk...     curang  kecurangan
# 1  Siaran Pers YLKI : Mendesak PT Pertamina untuk...     curang  kecurangan
# 2  Siaran Pers YLKI : Mendesak PT Pertamina untuk...     curang  kecurangan
# 3  Siaran Pers YLKI : Mendesak PT Pertamina untuk...     curang      curang
# 4  Siaran Pers YLKI : Mendesak PT Pertamina untuk...     sanksi      sanksi
# 5  Siaran Pers YLKI : Mendesak PT Pertamina untuk...     curang  kecurangan
# 6  Pertamina Patra Niaga Akan Bangun SPBU Skala U...    subsidi     subsidi
# 7  Pertamina Patra Niaga Akan Bangun SPBU Skala U...    subsidi     subsidi
# 8         Pertamina Jamin Stok BBM Jelang Mudik 2017    subsidi     subsidi
# 9         Pertamina Jamin Stok BBM Jelang Mudik 2017    subsidi     subsidi
#
#                                             sentence
# 0  Kejadian kecurangan takaran pada SPBU yang ter...
# 1  Sejak February 2016 YLKI telah mendapatkan inf...
# 2  PERTAMINA (Persero) segera melakukan pengawasa...
# 3  Agar PT Pertamina memberikan sanksi tegas pada...
# 4  Agar PT Pertamina memberikan sanksi tegas pada...
# 5  Selama ini kasus kecurangan SPBU hanya berhent...
# 6  Ditargetkan, tahun ini SPBU UKM berkapasitas 5...
# 7  "Jenis BBM medium, Pertalite, Dexlite, non sub...
# 8  Hal ini berlaku untuk semua jenis BBM, baik su...
# 9  Hal ini berlaku untuk semua jenis BBM, baik su...

# %%
df_matches.shape
# Out:
# (31, 4)

# %%
import warnings
# Menyembunyikan pesan peringatan agar output di GitHub bersih
warnings.filterwarnings("ignore")

from sklearn.feature_extraction.text import CountVectorizer
import nltk
from nltk.corpus import stopwords

# Memastikan stopwords terunduh secara diam-diam (tanpa progress bar)
nltk.download('stopwords', quiet=True)

# Get Indonesian stopwords
stop_words = set(stopwords.words('indonesian'))

# Use bigrams and trigrams
vectorizer = CountVectorizer(ngram_range=(2,3), stop_words=list(stop_words))

# Pastikan kolom 'Konten' diubah menjadi string untuk menghindari error
X = vectorizer.fit_transform(df['Konten'].dropna().astype(str))

# Get all n-grams
ngrams = vectorizer.get_feature_names_out()

# Search for n-grams containing Pertamina-related terms
target_terms = ["curang", "subsidi", "timbun", "sanksi"]
matches = [ng for ng in ngrams if any(term in ng for term in target_terms)]

print(f"🔹 N-grams yang mengandung kata {target_terms}:")

# Menampilkan hasilnya (dibatasi 50 agar jika datanya banyak, tidak memenuhi layar GitHub)
print(matches[:50])
# Out:
# 🔹 N-grams yang mengandung kata ['curang', 'subsidi', 'timbun', 'sanksi']:
# ['2022 bbm subsidi', 'bbm bersubsidi', 'bbm bersubsidi terpantau', 'bbm disubsidi', 'bbm disubsidi pemerintah', 'bbm non subsidi', 'bbm nonsubsidi', 'bbm nonsubsidi oktober', 'bbm nonsubsidi pertamina', 'bbm subsidi', 'bbm subsidi jenis', 'bbm subsidi menipis', 'bbm subsidi pertamina', 'bbm subsidi premium', 'bbm subsidi solar', 'bersubsidi terpantau', 'bersubsidi terpantau mengalami', 'biaya subsidi', 'biaya subsidi pemerintah', 'curang diputus', 'curang diputus kontrak', 'dexlite non subsidi', 'disubsidi pemerintah', 'disubsidi pemerintah menyasar', 'harga bbm nonsubsidi', 'hijau kecurangan', 'hijau kecurangan spbu', 'irto lpg subsidi', 'jenis bbm subsidi', 'kecurangan informasi', 'kecurangan informasi pt', 'kecurangan spbu', 'kecurangan spbu berhenti', 'kecurangan spbu pt', 'kecurangan takaran', 'kecurangan takaran spbu', 'kejadian kecurangan', 'kejadian kecurangan takaran', 'keluhan menengarai kecurangan', 'kuota bbm subsidi', 'liter bbm bersubsidi', 'liter bbm disubsidi', 'liter bbm subsidi', 'lpg non subsidi', 'lpg subsidi', 'lpg subsidi kg', 'meja hijau kecurangan', 'menengarai kecurangan', 'menengarai kecurangan spbu', 'minyak bbm subsidi']

# %%
import warnings
# Menyembunyikan pesan peringatan agar output di GitHub bersih
warnings.filterwarnings("ignore")

from sklearn.feature_extraction.text import CountVectorizer
import nltk
from nltk.corpus import stopwords
import pandas as pd

# Memastikan stopwords terunduh secara diam-diam (tanpa progress bar)
nltk.download('stopwords', quiet=True)

# Target lemma roots (Konteks Pertamina)
target_terms = ["curang", "subsidi", "timbun", "sanksi"]

# Get Indonesian stopwords
stop_words = set(stopwords.words('indonesian'))

# Use bigrams and trigrams
vectorizer = CountVectorizer(ngram_range=(2,3), stop_words=list(stop_words))

# Pastikan data berupa string saat di-fit transform
X = vectorizer.fit_transform(df['Konten'].dropna().astype(str))

# Map n-grams to frequencies
ngram_counts = X.sum(axis=0).A1
ngram_freq = dict(zip(vectorizer.get_feature_names_out(), ngram_counts))

# Filter only those containing target terms
matches = {ng: count for ng, count in ngram_freq.items()
           if any(term in ng for term in target_terms)}

# Convert to DataFrame
df_ngram_matches = pd.DataFrame(matches.items(), columns=["ngram", "count"]) \
                    .sort_values(by="count", ascending=False)

print(f"🔹 N-grams yang mengandung kata {target_terms}:")
display(df_ngram_matches.head(15))
# Out:
# 🔹 N-grams yang mengandung kata ['curang', 'subsidi', 'timbun', 'sanksi']:
#                         ngram  count
# 9                 bbm subsidi      7
# 52                non subsidi      7
# 43            lpg non subsidi      4
# 100        subsidi pemerintah      2
# 6              bbm nonsubsidi      2
# 31            kecurangan spbu      2
# 24       harga bbm nonsubsidi      2
# 10          bbm subsidi jenis      2
# 14          bbm subsidi solar      2
# 112   subsidi solar pertalite      2
# 111             subsidi solar      2
# 85              subsidi jenis      2
# 0            2022 bbm subsidi      1
# 8    bbm nonsubsidi pertamina      1
# 7      bbm nonsubsidi oktober      1

# %%
# Split ngrams into individual tokens and explode into rows
df_ngram_split = df_ngram_matches.copy()
df_ngram_split["tokens"] = df_ngram_split["ngram"].str.split()

# Explode so each token gets its own row
df_ngram_split = df_ngram_split.explode("tokens").reset_index(drop=True)

display(df_ngram_split.head(15))
# Out:
#                    ngram  count      tokens
# 0            bbm subsidi      7         bbm
# 1            bbm subsidi      7     subsidi
# 2            non subsidi      7         non
# 3            non subsidi      7     subsidi
# 4        lpg non subsidi      4         lpg
# 5        lpg non subsidi      4         non
# 6        lpg non subsidi      4     subsidi
# 7     subsidi pemerintah      2     subsidi
# 8     subsidi pemerintah      2  pemerintah
# 9         bbm nonsubsidi      2         bbm
# 10        bbm nonsubsidi      2  nonsubsidi
# 11       kecurangan spbu      2  kecurangan
# 12       kecurangan spbu      2        spbu
# 13  harga bbm nonsubsidi      2       harga
# 14  harga bbm nonsubsidi      2         bbm

# %%
import pandas as pd

# Example: df_ngram_matches comes from your n-gram extraction step
# It has columns ["ngram", "count"]

# 1. Split into tokens
df_ngram_split = df_ngram_matches.copy()
df_ngram_split["tokens"] = df_ngram_split["ngram"].str.split()

# 2. Explode so each token is its own row
df_ngram_split = df_ngram_split.explode("tokens").reset_index(drop=True)

# 3. Summarize token frequency (weighted by n-gram count)
token_summary = (
    df_ngram_split.groupby("tokens")["count"]
    .sum()
    .reset_index()
    .sort_values(by="count", ascending=False)
)

# Show results
print("🔹 Split n-grams into rows:")
display(df_ngram_split.head(10))

print("🔹 Token frequency summary:")
display(token_summary.head(10))
# Out:
# 🔹 Split n-grams into rows:
#                 ngram  count      tokens
# 0         bbm subsidi      7         bbm
# 1         bbm subsidi      7     subsidi
# 2         non subsidi      7         non
# 3         non subsidi      7     subsidi
# 4     lpg non subsidi      4         lpg
# 5     lpg non subsidi      4         non
# 6     lpg non subsidi      4     subsidi
# 7  subsidi pemerintah      2     subsidi
# 8  subsidi pemerintah      2  pemerintah
# 9      bbm nonsubsidi      2         bbm
# 🔹 Token frequency summary:
#         tokens  count
# 65     subsidi     95
# 6          bbm     34
# 43         non     21
# 22  kecurangan     19
# 44  nonsubsidi     10
# 52   pertamina     10
# 63       solar      9
# 46  pemerintah      9
# 21       jenis      7
# 32         lpg      7

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.corpus import stopwords
import nltk

# Ensure stopwords are downloaded
nltk.download('stopwords')

# load dataset
#df used in here

# Get Indonesian stopwords
stop_words = set(stopwords.words('indonesian'))

# ekstrak TF-IDF
vectorizer = TfidfVectorizer(stop_words=list(stop_words), max_features=20)
X = vectorizer.fit_transform(df["Konten"].dropna())
keywords = vectorizer.get_feature_names_out()

print("Kata kunci utama:", keywords)
# Out:
# Kata kunci utama: ['bbm' 'direktur' 'energi' 'harga' 'indonesia' 'jakarta' 'kapal'
#  'lingkungan' 'liter' 'masyarakat' 'minyak' 'nasional' 'persero'
#  'pertamina' 'perusahaan' 'program' 'pt' 'rp' 'spbu' 'tangki']
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# !pip install python-rake -q

# %%
# !pip install rake-nltk
# Out:
# Requirement already satisfied: rake-nltk in /usr/local/lib/python3.12/dist-packages (1.0.6)
# Requirement already satisfied: nltk<4.0.0,>=3.6.2 in /usr/local/lib/python3.12/dist-packages (from rake-nltk) (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from nltk<4.0.0,>=3.6.2->rake-nltk) (8.3.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from nltk<4.0.0,>=3.6.2->rake-nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.12/dist-packages (from nltk<4.0.0,>=3.6.2->rake-nltk) (2025.11.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from nltk<4.0.0,>=3.6.2->rake-nltk) (4.67.3)

# %%
from rake_nltk import Rake
import nltk
from nltk.corpus import stopwords
import pandas as pd

# Ensure stopwords are downloaded
nltk.download("stopwords")

# Initialize RAKE with Indonesian stopwords
stop_words = set(stopwords.words("indonesian"))
r = Rake(stopwords=list(stop_words))

# Function to extract RAKE keywords for a document
def extract_rake_keywords(text, top_n=10):
    if pd.isna(text):
        return []
    r.extract_keywords_from_text(text)
    return r.get_ranked_phrases_with_scores()[:top_n]

# Apply to all articles
df["rake_keywords"] = df["Konten"].apply(lambda x: extract_rake_keywords(x, top_n=10))

# Flatten results for analysis
all_rake_keywords = []
for idx, row in df.iterrows():
    for score, phrase in row["rake_keywords"]:
        all_rake_keywords.append({
            "doc_id": idx,
            "title": row["Judul"],
            "score": score,
            "keyword": phrase
        })

df_rake = pd.DataFrame(all_rake_keywords)

# Show results
print("🔹 Sample RAKE keywords per document:")
display(df[["Judul", "rake_keywords"]].head(5))

print("🔹 Flattened RAKE keyword table:")
display(df_rake.head(10))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 🔹 Sample RAKE keywords per document:
#                                                Judul  \
# 0  Siaran Pers YLKI : Mendesak PT Pertamina untuk...
# 1  Pertamina Kembangkan Program Non-Tunai Pembeli...
# 2   Pertamina Tak Masalahkan Nama Pertamini, tapi...
# 3  Pertamina Patra Niaga Akan Bangun SPBU Skala U...
# 4  Gaji Manajer 'Engineering' Chevron Rp 51,25 Ju...
#
#                                        rake_keywords
# 0  [(16.0, berdasarkan pantauan bph migas), (15.5...
# 1  [(34.3, pt pertamina mensosialisasikan program...
# 2  [(108.17027417027418, beluk kios bbm eceran pe...
# 3  [(78.92857142857143, anak usaha pt pertamina b...
# 4  [(21.0, tren penurunan harga minyak dunia), (2...
# 🔹 Flattened RAKE keyword table:
#    doc_id                                              title      score  \
# 0       0  Siaran Pers YLKI : Mendesak PT Pertamina untuk...  16.000000
# 1       0  Siaran Pers YLKI : Mendesak PT Pertamina untuk...  15.500000
# 2       0  Siaran Pers YLKI : Mendesak PT Pertamina untuk...   9.500000
# 3       0  Siaran Pers YLKI : Mendesak PT Pertamina untuk...   9.000000
# 4       0  Siaran Pers YLKI : Mendesak PT Pertamina untuk...   9.000000
# 5       0  Siaran Pers YLKI : Mendesak PT Pertamina untuk...   9.000000
# 6       0  Siaran Pers YLKI : Mendesak PT Pertamina untuk...   9.000000
# 7       0  Siaran Pers YLKI : Mendesak PT Pertamina untuk...   8.500000
# 8       0  Siaran Pers YLKI : Mendesak PT Pertamina untuk...   7.857143
# 9       0  Siaran Pers YLKI : Mendesak PT Pertamina untuk...   7.750000
#
#                                    keyword
# 0           berdasarkan pantauan bph migas
# 1  direktur jenderal perlindungan konsumen
# 2          mengakibatkan kerugian konsumen
# 3                      wilayah sumatera yg
# 4                         ranah meja hijau
# 5             diputus kontrak kemitraannya
# 6                        daftar black list
# 7                       february 2016 ylki
# 8                    minimal pimpinan spbu
# 9              kejadian kecurangan takaran

# %%
df_rake.shape
# Out:
# (500, 4)

# %%
# !pip install sumy
# Out:
# Requirement already satisfied: sumy in /usr/local/lib/python3.12/dist-packages (0.12.0)
# Requirement already satisfied: breadability>=0.1.20 in /usr/local/lib/python3.12/dist-packages (from sumy) (0.1.20)
# Requirement already satisfied: docopt-ng>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from sumy) (0.9.0)
# Requirement already satisfied: lxml-html-clean in /usr/local/lib/python3.12/dist-packages (from sumy) (0.4.4)
# Requirement already satisfied: nltk>=3.0.2 in /usr/local/lib/python3.12/dist-packages (from sumy) (3.9.1)
# Requirement already satisfied: pycountry>=18.2.23 in /usr/local/lib/python3.12/dist-packages (from sumy) (26.2.16)
# Requirement already satisfied: requests>=2.7.0 in /usr/local/lib/python3.12/dist-packages (from sumy) (2.32.4)
# Requirement already satisfied: setuptools>=65.0.0 in /usr/local/lib/python3.12/dist-packages (from sumy) (75.2.0)
# Requirement already satisfied: docopt<0.7,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from breadability>=0.1.20->sumy) (0.6.2)
# Requirement already satisfied: chardet in /usr/local/lib/python3.12/dist-packages (from breadability>=0.1.20->sumy) (5.2.0)
# Requirement already satisfied: lxml>=2.0 in /usr/local/lib/python3.12/dist-packages (from breadability>=0.1.20->sumy) (6.0.2)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from nltk>=3.0.2->sumy) (8.3.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from nltk>=3.0.2->sumy) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.12/dist-packages (from nltk>=3.0.2->sumy) (2025.11.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from nltk>=3.0.2->sumy) (4.67.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.7.0->sumy) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.7.0->sumy) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.7.0->sumy) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.7.0->sumy) (2026.2.25)

# %%
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')

from sumy.parsers.plaintext import PlaintextParser
from sumy.nlp.tokenizers import Tokenizer
from sumy.summarizers.text_rank import TextRankSummarizer

# Initialize TextRank
summarizer = TextRankSummarizer()

# Function to extract TextRank key sentences or phrases
def extract_textrank_keywords(text, top_n=5):
    if pd.isna(text) or not isinstance(text, str):
        return []
    try:
        parser = PlaintextParser.from_string(text, Tokenizer("indonesian"))
    except LookupError:
        parser = PlaintextParser.from_string(text, Tokenizer("english"))
    summary = summarizer(parser.document, top_n)
    return [str(sentence) for sentence in summary]


# Apply to all articles
df["textrank_keywords"] = df["Konten"].apply(lambda x: extract_textrank_keywords(x, top_n=5))

# Flatten results into table
all_textrank_keywords = []
for idx, row in df.iterrows():
    for phrase in row["textrank_keywords"]:
        all_textrank_keywords.append({
            "doc_id": idx,
            "title": row["Judul"],
            "keyword": phrase
        })

df_textrank = pd.DataFrame(all_textrank_keywords)

# Show results
print("🔹 Sample TextRank keywords per document:")
display(df[["Judul", "textrank_keywords"]].head(5))

print("🔹 Flattened TextRank keyword table:")
display(df_textrank.head(10))
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# 🔹 Sample TextRank keywords per document:
#                                                Judul  \
# 0  Siaran Pers YLKI : Mendesak PT Pertamina untuk...
# 1  Pertamina Kembangkan Program Non-Tunai Pembeli...
# 2   Pertamina Tak Masalahkan Nama Pertamini, tapi...
# 3  Pertamina Patra Niaga Akan Bangun SPBU Skala U...
# 4  Gaji Manajer 'Engineering' Chevron Rp 51,25 Ju...
#
#                                    textrank_keywords
# 0  [Kejadian kecurangan takaran pada SPBU yang te...
# 1  [PONTIANAK, KOMPAS.com - PT Pertamina mensosia...
# 2  [Berbeda dengan kios-kios biasa yang menggunak...
# 3  [JAKARTA, KOMPAS.com - PT Pertamina Patra Niag...
# 4  [Di tengah melemahnya harga minyak, perusahaan...
# 🔹 Flattened TextRank keyword table:
#    doc_id                                              title  \
# 0       0  Siaran Pers YLKI : Mendesak PT Pertamina untuk...
# 1       0  Siaran Pers YLKI : Mendesak PT Pertamina untuk...
# 2       0  Siaran Pers YLKI : Mendesak PT Pertamina untuk...
# 3       0  Siaran Pers YLKI : Mendesak PT Pertamina untuk...
# 4       0  Siaran Pers YLKI : Mendesak PT Pertamina untuk...
# 5       1  Pertamina Kembangkan Program Non-Tunai Pembeli...
# 6       1  Pertamina Kembangkan Program Non-Tunai Pembeli...
# 7       1  Pertamina Kembangkan Program Non-Tunai Pembeli...
# 8       1  Pertamina Kembangkan Program Non-Tunai Pembeli...
# 9       1  Pertamina Kembangkan Program Non-Tunai Pembeli...
#
#                                              keyword
# 0  Kejadian kecurangan takaran pada SPBU yang ter...
# 1  PERTAMINA (Persero) pada bulan Maret yang lalu...
# 2  PERTAMINA (Persero) segera melakukan pengawasa...
# 3  Agar PT Pertamina memberikan sanksi tegas pada...
# 4  Namun demikian bukan hanya pada pelaku lapanga...
# 5  PONTIANAK, KOMPAS.com - PT Pertamina mensosial...
# 6  Sales Eksekutif BBM Pertamina Pontianak, Arwin...
# 7  "Tapi yang saat ini untuk tahap awal sosialisa...
# 8  Saat ini, seluruh SPBU yang ada di Pontianak s...
# 9  Uang elektronik di SPBU ini akan mulai diberla...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.corpus import stopwords

# Get Indonesian stopwords from NLTK
stop_words = stopwords.words("indonesian")

vectorizer = TfidfVectorizer(max_features=10, stop_words=stop_words)
X = vectorizer.fit_transform(df["Konten"].fillna(""))

tfidf_feature_names = vectorizer.get_feature_names_out()

def extract_tfidf_keywords(doc_index, top_n=5):
    row = X[doc_index].toarray().flatten()
    top_indices = row.argsort()[::-1][:top_n]
    return [tfidf_feature_names[i] for i in top_indices if row[i] > 0]

# %%
# ✅ Install needed packages
# !pip install rake-nltk sumy openpyxl

import nltk
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
from rake_nltk import Rake
from sumy.parsers.plaintext import PlaintextParser
from sumy.nlp.tokenizers import Tokenizer
from sumy.summarizers.text_rank import TextRankSummarizer
import pandas as pd

# Download NLTK resources
nltk.download('punkt')
nltk.download('stopwords')

# --- 1. TF-IDF Setup ---
stop_words = stopwords.words("indonesian")
vectorizer = TfidfVectorizer(max_features=50, stop_words=stop_words)
X = vectorizer.fit_transform(df["Konten"].fillna(""))
tfidf_feature_names = vectorizer.get_feature_names_out()

def extract_tfidf_keywords(doc_index, top_n=5):
    row = X[doc_index].toarray().flatten()
    top_indices = row.argsort()[::-1][:top_n]
    return [tfidf_feature_names[i] for i in top_indices if row[i] > 0]

# --- 2. RAKE Setup ---
r = Rake(stopwords=stop_words)

def extract_rake_keywords(text, top_n=5):
    if pd.isna(text):
        return []
    r.extract_keywords_from_text(text)
    return [phrase for score, phrase in r.get_ranked_phrases_with_scores()[:top_n]]

# --- 3. TextRank Setup ---
summarizer = TextRankSummarizer()

def extract_textrank_keywords(text, top_n=3):
    if pd.isna(text) or not isinstance(text, str):
        return []
    try:
        parser = PlaintextParser.from_string(text, Tokenizer("indonesian"))
    except LookupError:
        parser = PlaintextParser.from_string(text, Tokenizer("english"))
    summary = summarizer(parser.document, top_n)
    return [str(sentence) for sentence in summary]

# --- 4. Apply all methods to ALL documents ---
comparison_results = []
tfidf_results = []
rake_results = []
textrank_results = []

for idx in range(len(df)):
    text = df.loc[idx, "Konten"]
    title = df.loc[idx, "Judul"]

    tfidf_kw = extract_tfidf_keywords(idx, top_n=5)
    rake_kw = extract_rake_keywords(text, top_n=5)
    textrank_kw = extract_textrank_keywords(text, top_n=3)

    comparison_results.append({
        "doc_id": idx,
        "title": title,
        "TF-IDF": tfidf_kw,
        "RAKE": rake_kw,
        "TextRank": textrank_kw
    })

    for kw in tfidf_kw:
        tfidf_results.append({"doc_id": idx, "title": title, "keyword": kw})
    for kw in rake_kw:
        rake_results.append({"doc_id": idx, "title": title, "keyword": kw})
    for kw in textrank_kw:
        textrank_results.append({"doc_id": idx, "title": title, "keyword": kw})

# DataFrames
df_comparison = pd.DataFrame(comparison_results)
df_tfidf = pd.DataFrame(tfidf_results)
df_rake = pd.DataFrame(rake_results)
df_textrank = pd.DataFrame(textrank_results)

# --- 5. Export to Excel with multiple sheets ---
output_file = "pertamina_keywords_comparison.xlsx"
with pd.ExcelWriter(output_file, engine="openpyxl") as writer:
    df_tfidf.to_excel(writer, sheet_name="TF-IDF", index=False)
    df_rake.to_excel(writer, sheet_name="RAKE", index=False)
    df_textrank.to_excel(writer, sheet_name="TextRank", index=False)
    df_comparison.to_excel(writer, sheet_name="Comparison", index=False)

print(f"✅ Exported all results to {output_file}")
# Out:
# Requirement already satisfied: rake-nltk in /usr/local/lib/python3.12/dist-packages (1.0.6)
# Requirement already satisfied: sumy in /usr/local/lib/python3.12/dist-packages (0.12.0)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.12/dist-packages (3.1.5)
# Requirement already satisfied: nltk<4.0.0,>=3.6.2 in /usr/local/lib/python3.12/dist-packages (from rake-nltk) (3.9.1)
# Requirement already satisfied: breadability>=0.1.20 in /usr/local/lib/python3.12/dist-packages (from sumy) (0.1.20)
# Requirement already satisfied: docopt-ng>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from sumy) (0.9.0)
# Requirement already satisfied: lxml-html-clean in /usr/local/lib/python3.12/dist-packages (from sumy) (0.4.4)
# Requirement already satisfied: pycountry>=18.2.23 in /usr/local/lib/python3.12/dist-packages (from sumy) (26.2.16)
# Requirement already satisfied: requests>=2.7.0 in /usr/local/lib/python3.12/dist-packages (from sumy) (2.32.4)
# Requirement already satisfied: setuptools>=65.0.0 in /usr/local/lib/python3.12/dist-packages (from sumy) (75.2.0)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.12/dist-packages (from openpyxl) (2.0.0)
# Requirement already satisfied: docopt<0.7,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from breadability>=0.1.20->sumy) (0.6.2)
# Requirement already satisfied: chardet in /usr/local/lib/python3.12/dist-packages (from breadability>=0.1.20->sumy) (5.2.0)
# Requirement already satisfied: lxml>=2.0 in /usr/local/lib/python3.12/dist-packages (from breadability>=0.1.20->sumy) (6.0.2)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from nltk<4.0.0,>=3.6.2->rake-nltk) (8.3.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from nltk<4.0.0,>=3.6.2->rake-nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.12/dist-packages (from nltk<4.0.0,>=3.6.2->rake-nltk) (2025.11.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from nltk<4.0.0,>=3.6.2->rake-nltk) (4.67.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.7.0->sumy) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.7.0->sumy) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.7.0->sumy) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.7.0->sumy) (2026.2.25)
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ✅ Exported all results to pertamina_keywords_comparison.xlsx

# %%
df_comparison
# Out:
#     doc_id                                              title  \
# 0        0  Siaran Pers YLKI : Mendesak PT Pertamina untuk...
# 1        1  Pertamina Kembangkan Program Non-Tunai Pembeli...
# 2        2   Pertamina Tak Masalahkan Nama Pertamini, tapi...
# 3        3  Pertamina Patra Niaga Akan Bangun SPBU Skala U...
# 4        4  Gaji Manajer 'Engineering' Chevron Rp 51,25 Ju...
# 5        5          Dirut dan Wadirut Pertamina Resmi Dicopot
# 6        6         Pertamina Jamin Stok BBM Jelang Mudik 2017
# 7        7         BBM Kemasan Pertamina Tanpa Terima Pesanan
# 8        8   Pertamina Siapkan BBM Kemasan Satu dan Dua Liter
# 9        9  Jaga Pasokan Energi, Pertamina Perkuat Monitor...
# 10      10  2 Kapal Pertamina Keluar Area Konflik Timur Te...
# 11      11  Sambut Arus Mudik 2026, Komut Pertamina Tinjau...
# 12      12  Pertamina Dorong Puluhan UMKM Lebih Aktif dan ...
# 13      13  Pertamina Naikkan Harga BBM per 1 Maret, Perta...
# 14      14  Gagalkan Pencurian Minyak, Pertamina Jaga Keta...
# 12  [pertamina, produk, penghargaan, lingkungan, m...
# 13             [harga, liter, bbm, pertamina, produk]
# 14                  [truk, minyak, migas, tangki, 10]
# 15         [energi, nasional, kerja, indonesia, juta]
# 16       [bbm, distribusi, pertamina, kapal, kondisi]
# 17         [kapal, kondisi, patra, proses, pertamina]
# 18  [kapal, energi, distribusi, pertamina, perusah...
# 19  [program, penghargaan, pertamina, masyarakat, ...
# 20  [lingkungan, pertamina, indonesia, kondisi, ma...
# 21  [program, lingkungan, sekolah, masyarakat, per...
# 22  [negara, pemerintah, pertamina, nasional, dire...
# 23     [kerja, nicke, pertamina, nasional, indonesia]
# 24    [pertamina, energi, program, perusahaan, nicke]
# 25              [harga, bbm, patra, indonesia, bahan]
# 26             [bbm, liter, juta, proses, pemerintah]
# 27                       [liter, rp, 000, harga, bbm]
# 28  [sekolah, lingkungan, program, energi, pertamina]
# 29                     [us, miliar, juta, minyak, rp]
# 30            [harga, rp, 000, pertamina, pemerintah]
# 31               [truk, tangki, mengalami, pertamina]
# 32          [mengalami, bakar, tangki, bahan, minyak]
# 33        [program, negara, pertamina, jakarta, 2018]
# 34       [kecelakaan, truk, tangki, liter, pertamina]
# 35        [smartmt, mobil, tangki, kecelakaan, patra]
# 36        [smartmt, mobil, tangki, kecelakaan, patra]
# 37            [sesuai, pertamina, proses, produk, pt]
# 38      [energi, program, lingkungan, 2019, memiliki]
# 39       [nicke, 2018, proses, perusahaan, pertamina]
# 40         [pertamina, nasional, energi, 2019, nicke]
# 41   [2018, pertamina, penghargaan, indonesia, utama]
# 42         [pertamina, rp, negara, 2018, penghargaan]
# 43     [energi, 2018, indonesia, nasional, pertamina]
# 44           [penghargaan, patra, kerja, migas, 2019]
# 45                 [miliar, rp, negara, proses, juta]
# 46                [jakarta, miliar, 2019, sesuai, rp]
# 47               [spbu, 2019, pertamina, persero, pt]
# 48                  [miliar, rp, 2018, utama, negara]
# 49       [direktur, utama, nicke, pertamina, jakarta]
#
#                                                  RAKE  \
# 0   [berdasarkan pantauan bph migas, direktur jend...
# 1   [pt pertamina mensosialisasikan program penggu...
# 2   [beluk kios bbm eceran pertamini head of marke...
# 3   [anak usaha pt pertamina berencana membangun s...
# 4   [tren penurunan harga minyak dunia, tingkat ke...
# 5   [com — kementerian badan usaha milik negara, d...
# 6   [menambah armada mobil tangki beserta awaknya,...
# 7   [pertamina menyediakan 83 unit sepeda motor, m...
# 8   [area manager communication and relation jbb m...
# 9   [vice president corporate communication pt per...
# 10  [menjalankan misi pengangkutan minyak mentah j...
# 11  [cnn indonesia -- komisaris utama pt pertamina...
# 12  [pertamina berharap umkm binaan memperoleh man...
# 13  [cnn indonesia -- pt pertamina, harga bbm jeni...
# 14  [cnn indonesia -- upaya pencurian minyak menta...
# 15  [cnn indonesia -- holding industri pertambanga...
# 16  [peningkatan kualitas mitigasi kelangkaan bbm ...
# 17  [ksop kelas iii tanjung pakis langsung bergera...
# 18  [kapal gamsunoro melayani kargo milik konsumen...
# 19  [rp 600 juta total pendapatan kelompok sadar w...
# 23  [Kerja sama ini ditandai dengan penandatangana...
# 24  [Mengusung tema "Energizing The Nation", punca...
# 25  [Adapun sebarannya, yakni 63 lembaga penyalur ...
# 26  [Ia menjelaskan, pihaknya juga telah membuka b...
# 27  [Tercatat, kenaikan tertinggi dialami Pertamin...
# 28  [Mengangkat tema “Energizing Sustainable Commu...
# 29  [Berdasarkan laporan keuangan Pertamina (audit...
# 30  [JAKARTA – PT Pertamina (Persero) mengklaim ha...
# 31  [Petugas berusaha menetralkan gas pada truk ta...
# 32  [Sebanyak lima orang mengalami luka berat, 15 ...
# 33  ["Pertamina Foundation tetap menghormati prose...
# 34  ["Jadi kecelakaan tunggal truk tangki Pertamin...
# 35  [Menurut Isabella Hutahean, Direktur SDM dan P...
# 36  [Sementara itu Direktur SDM dan Penunjang Bisn...
# 37  [Sesuai arahan Presiden Republik Indonesia, Jo...
# 38  [PT Pertamina (Persero) Marketing Operation Re...
# 39  [Namun Presiden Joko Widodo (Jokowi) pernah me...
# 40  [Untuk memaksimalkan produksi dari lapangan ya...
# 41  ["Pertamina terus melakukan improvement dengan...
# 42  [Jakarta - PT Pertamina (Persero) memberikan s...
# 43  [Jakarta - Pertamina akan menggelar Pertamina ...
# 44  [Dengan catatan 23.449.699 jam kerja aman, dar...
# 45  ["Jika terpidana tidak mempunyai harta yang cu...
# 46  [Menurut dia, putusan majelis hakim hanya meng...
# 47  ["Pihak SPBU bertindak cepat dan segera menona...
# 48  [Menanggapi hal itu, Direktur Pemasaran Korpor...
# 49  [Lebih lanjut dijelaskan bahwa surat keputusan...

# %% [markdown]
# ## 6. Text Embeddings
#
# Text embeddings are numerical representations of text that capture semantic meaning. We can use embeddings to analyze the similarity between documents or words.
#
# ### 6.1 Using Pre-trained Embeddings
#
# We can use pre-trained embeddings to leverage knowledge from large datasets. Sentence-BERT is a popular choice for generating sentence and document embeddings.

# %%
# !pip install sentence-transformers -q

# %%
import os
import warnings

# 1. Mematikan progress bar download dari Hugging Face Hub
os.environ['HF_HUB_DISABLE_PROGRESS_BARS'] = '1'

# 2. Menyembunyikan pesan peringatan/warnings (seperti "UNEXPECTED key")
warnings.filterwarnings("ignore")

# 3. Mematikan log dan progress bar loading dari library Transformers
import transformers
transformers.logging.set_verbosity_error()
transformers.logging.disable_progress_bar()

from sentence_transformers import SentenceTransformer

# Load model (sekarang proses ini akan benar-benar sunyi/tanpa output teks)
model = SentenceTransformer('paraphrase-multilingual-MiniLM-L12-v2')

# Generate embeddings for the 'Konten' column
sentences = df['Konten'].astype(str).tolist()
embeddings = model.encode(sentences)

print("Shape of embeddings:", embeddings.shape)
# Out:
# Shape of embeddings: (50, 384)

# %% [markdown]
# Now that we have the embeddings, we can use them for various downstream tasks, such as:
#
# - **Document Similarity:** Calculate the similarity between articles.
# - **Clustering:** Group similar articles together.
# - **Visualization:** Visualize the embeddings to see relationships between articles.

# %%
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd

# Calculate cosine similarity matrix
similarity_matrix = cosine_similarity(embeddings)

# Convert to a DataFrame for better readability
similarity_df = pd.DataFrame(similarity_matrix, index=df['Judul'], columns=df['Judul'])

print("Cosine Similarity Matrix (first 5 rows and columns):")
display(similarity_df.head())

# You can also find the most similar documents to a specific document
# Example: Find most similar documents to the first document
document_index_to_compare = 0
similarity_scores = similarity_df.iloc[document_index_to_compare].sort_values(ascending=False)

print(f"\nMost similar documents to '{df['Judul'][document_index_to_compare]}':")
# Display top 6, excluding the document itself (similarity score of 1)
display(similarity_scores.head(6))
# Out:
# Cosine Similarity Matrix (first 5 rows and columns):
# Judul                                               Siaran Pers YLKI : Mendesak PT Pertamina untuk Perketat Pengawasan SPBU  \
# Judul
# Siaran Pers YLKI : Mendesak PT Pertamina untuk ...                                           1.000000
# Pertamina Kembangkan Program Non-Tunai Pembelia...                                           0.536759
# Pertamina Tak Masalahkan Nama Pertamini, tapi...                                             0.315723
# Pertamina Patra Niaga Akan Bangun SPBU Skala UK...                                           0.440310
# Gaji Manajer 'Engineering' Chevron Rp 51,25 Jut...                                           0.451505
#
# Judul                                               Pertamina Kembangkan Program Non-Tunai Pembelian BBM di SPBU  \
# Judul
# Siaran Pers YLKI : Mendesak PT Pertamina untuk ...                                           0.536759
# Pertamina Kembangkan Program Non-Tunai Pembelia...                                           1.000000
# Pertamina Tak Masalahkan Nama Pertamini, tapi...                                             0.463539
# Pertamina Patra Niaga Akan Bangun SPBU Skala UK...                                           0.632849
# Gaji Manajer 'Engineering' Chevron Rp 51,25 Jut...                                           0.438267
#
# Judul                                               Pertamina Tak Masalahkan Nama Pertamini, tapi...  \
# Judul
# Siaran Pers YLKI : Mendesak PT Pertamina untuk ...                                          0.315723
# Pertamina Kembangkan Program Non-Tunai Pembelia...                                          0.463539
# Pertamina Tak Masalahkan Nama Pertamini, tapi...                                            1.000000
# Pertamina Patra Niaga Akan Bangun SPBU Skala UK...                                          0.417988
# Gaji Manajer 'Engineering' Chevron Rp 51,25 Jut...                                          0.274355
#
# Judul                                               Pertamina Patra Niaga Akan Bangun SPBU Skala UKM di Berbagai Pelosok  \
# Judul
# Siaran Pers YLKI : Mendesak PT Pertamina untuk ...                                           0.440310
# Pertamina Kembangkan Program Non-Tunai Pembelia...                                           0.632849
# Pertamina Tak Masalahkan Nama Pertamini, tapi...                                             0.417988
# Pertamina Patra Niaga Akan Bangun SPBU Skala UK...                                           1.000000
# Gaji Manajer 'Engineering' Chevron Rp 51,25 Jut...                                           0.421354
#
# Judul                                               Gaji Manajer 'Engineering' Chevron Rp 51,25 Juta, di Pertamina Rp 13,3 Juta per Bulan\r\n  \
# Judul
# Siaran Pers YLKI : Mendesak PT Pertamina untuk ...                                           0.451505
# Pertamina Kembangkan Program Non-Tunai Pembelia...                                           0.438267
# Pertamina Tak Masalahkan Nama Pertamini, tapi...                                             0.274355
# Pertamina Patra Niaga Akan Bangun SPBU Skala UK...                                           0.421354
# Gaji Manajer 'Engineering' Chevron Rp 51,25 Jut...                                           1.000000
#
# Judul                                               Dirut dan Wadirut Pertamina Resmi Dicopot  \
# Judul
# Siaran Pers YLKI : Mendesak PT Pertamina untuk ...                                   0.534415
# Pertamina Kembangkan Program Non-Tunai Pembelia...                                   0.573116
# Pertamina Tak Masalahkan Nama Pertamini, tapi...                                     0.488601
# Pertamina Patra Niaga Akan Bangun SPBU Skala UK...                                   0.675482
# Gaji Manajer 'Engineering' Chevron Rp 51,25 Jut...                                   0.334096
#
# Judul                                               Pertamina Jamin Stok BBM Jelang Mudik 2017  \
# Judul
# Siaran Pers YLKI : Mendesak PT Pertamina untuk ...                                    0.557734
# Pertamina Kembangkan Program Non-Tunai Pembelia...                                    0.742705
# Pertamina Tak Masalahkan Nama Pertamini, tapi...                                      0.505132
# Pertamina Patra Niaga Akan Bangun SPBU Skala UK...                                    0.635004
# Gaji Manajer 'Engineering' Chevron Rp 51,25 Jut...                                    0.412714
#
# Judul                                               BBM Kemasan Pertamina Tanpa Terima Pesanan  \
# Judul
# Siaran Pers YLKI : Mendesak PT Pertamina untuk ...                                    0.478986
# Pertamina Kembangkan Program Non-Tunai Pembelia...                                    0.679897
# Pertamina Tak Masalahkan Nama Pertamini, tapi...                                      0.530472
# Pertamina Patra Niaga Akan Bangun SPBU Skala UK...                                    0.591110
# Gaji Manajer 'Engineering' Chevron Rp 51,25 Jut...                                    0.422536
#
# Judul                                               Pertamina Siapkan BBM Kemasan Satu dan Dua Liter  \
# Judul
# Siaran Pers YLKI : Mendesak PT Pertamina untuk ...                                          0.443185
# Pertamina Kembangkan Program Non-Tunai Pembelia...                                          0.664735
# Pertamina Tak Masalahkan Nama Pertamini, tapi...                                            0.496407
# Pertamina Patra Niaga Akan Bangun SPBU Skala UK...                                          0.643907
# Gaji Manajer 'Engineering' Chevron Rp 51,25 Jut...                                          0.323620
#
# Judul                                               Jaga Pasokan Energi, Pertamina Perkuat Monitoring lewat Digital Hub  \
# Judul
# Siaran Pers YLKI : Mendesak PT Pertamina untuk ...                                           0.460873
# Pertamina Kembangkan Program Non-Tunai Pembelia...                                           0.611319
# Pertamina Tak Masalahkan Nama Pertamini, tapi...                                             0.472918
# Pertamina Patra Niaga Akan Bangun SPBU Skala UK...                                           0.672387
# Gaji Manajer 'Engineering' Chevron Rp 51,25 Jut...                                           0.257408
#
# Judul                                               ...  \
# Judul                                               ...
# Siaran Pers YLKI : Mendesak PT Pertamina untuk ...  ...
# Pertamina Kembangkan Program Non-Tunai Pembelia...  ...
# Pertamina Tak Masalahkan Nama Pertamini, tapi...    ...
# Pertamina Patra Niaga Akan Bangun SPBU Skala UK...  ...
# Gaji Manajer 'Engineering' Chevron Rp 51,25 Jut...  ...
#
# Judul                                               62 Tahun Usia Pertamina, Apa yang Telah Diberikan untuk Tanah Air?  \
# Judul
# Siaran Pers YLKI : Mendesak PT Pertamina untuk ...                                           0.429994
# Pertamina Kembangkan Program Non-Tunai Pembelia...                                           0.523859
# Pertamina Tak Masalahkan Nama Pertamini, tapi...                                             0.387947
# Pertamina Patra Niaga Akan Bangun SPBU Skala UK...                                           0.542672
# Gaji Manajer 'Engineering' Chevron Rp 51,25 Jut...                                           0.317469
#
# Judul                                               Dirut Pertamina Terpilih Jadi TOP Leader in IT Leadership 2018  \
# Judul
# Siaran Pers YLKI : Mendesak PT Pertamina untuk ...                                           0.360236
# Pertamina Kembangkan Program Non-Tunai Pembelia...                                           0.440635
# Pertamina Tak Masalahkan Nama Pertamini, tapi...                                             0.295630
# Pertamina Patra Niaga Akan Bangun SPBU Skala UK...                                           0.564543
# Gaji Manajer 'Engineering' Chevron Rp 51,25 Jut...                                           0.328073
#
# Judul                                               Pertamina Setor ke Negara Rp 120 Triliun di 2018  \
# Judul
# Siaran Pers YLKI : Mendesak PT Pertamina untuk ...                                          0.512744
# Pertamina Kembangkan Program Non-Tunai Pembelia...                                          0.592760
# Pertamina Tak Masalahkan Nama Pertamini, tapi...                                            0.412697
# Pertamina Patra Niaga Akan Bangun SPBU Skala UK...                                          0.620971
# Gaji Manajer 'Engineering' Chevron Rp 51,25 Jut...                                          0.480733
#
# Judul                                               Pertamina akan Bahas Potensi Energi Dalam Negeri di PEF 2018  \
# Judul
# Siaran Pers YLKI : Mendesak PT Pertamina untuk ...                                           0.332728
# Pertamina Kembangkan Program Non-Tunai Pembelia...                                           0.560372
# Pertamina Tak Masalahkan Nama Pertamini, tapi...                                             0.365577
# Pertamina Patra Niaga Akan Bangun SPBU Skala UK...                                           0.710249
# Gaji Manajer 'Engineering' Chevron Rp 51,25 Jut...                                           0.319540
#
# Judul                                               Pertamina MOR III Raih Patra Nirbaya Karya Pratama  \
# Judul
# Siaran Pers YLKI : Mendesak PT Pertamina untuk ...                                           0.556797
# Pertamina Kembangkan Program Non-Tunai Pembelia...                                           0.485160
# Pertamina Tak Masalahkan Nama Pertamini, tapi...                                             0.315715
# Pertamina Patra Niaga Akan Bangun SPBU Skala UK...                                           0.615892
# Gaji Manajer 'Engineering' Chevron Rp 51,25 Jut...                                           0.487935
#
# Judul                                               Korupsi Rp 612 M, Eks Presdir Dana Pensiun Pertamina Dibui 8 Tahun  \
# Judul
# Siaran Pers YLKI : Mendesak PT Pertamina untuk ...                                           0.403645
# Pertamina Kembangkan Program Non-Tunai Pembelia...                                           0.266999
# Pertamina Tak Masalahkan Nama Pertamini, tapi...                                             0.082187
# Pertamina Patra Niaga Akan Bangun SPBU Skala UK...                                           0.170502
# Gaji Manajer 'Engineering' Chevron Rp 51,25 Jut...                                           0.213155
#
# Judul                                               Divonis 8 Tahun Bui, Eks Dirkeu Pertamina Sebut Hakim Abaikan Fakta  \
# Judul
# Siaran Pers YLKI : Mendesak PT Pertamina untuk ...                                           0.331689
# Pertamina Kembangkan Program Non-Tunai Pembelia...                                           0.230729
# Pertamina Tak Masalahkan Nama Pertamini, tapi...                                             0.047469
# Pertamina Patra Niaga Akan Bangun SPBU Skala UK...                                           0.168369
# Gaji Manajer 'Engineering' Chevron Rp 51,25 Jut...                                           0.123577
#
# Judul                                               Totem SPBU Medan Diretas, Ini Penjelasan Pertamina  \
# Judul
# Siaran Pers YLKI : Mendesak PT Pertamina untuk ...                                           0.520415
# Pertamina Kembangkan Program Non-Tunai Pembelia...                                           0.455255
# Pertamina Tak Masalahkan Nama Pertamini, tapi...                                             0.138876
# Pertamina Patra Niaga Akan Bangun SPBU Skala UK...                                           0.350511
# Gaji Manajer 'Engineering' Chevron Rp 51,25 Jut...                                           0.153647
#
# Judul                                               Gaji Direksi dan Komisaris Rp 3,2 Miliar Per Bulan, Ini Kata Pertamina  \
# Judul
# Siaran Pers YLKI : Mendesak PT Pertamina untuk ...                                           0.480424
# Pertamina Kembangkan Program Non-Tunai Pembelia...                                           0.510342
# Pertamina Tak Masalahkan Nama Pertamini, tapi...                                             0.257536
# Pertamina Patra Niaga Akan Bangun SPBU Skala UK...                                           0.424236
# Gaji Manajer 'Engineering' Chevron Rp 51,25 Jut...                                           0.492085
#
# Judul                                               Direksi Pertamina Kembali Dirombak, Dirut dan 4 Direktur Dicopot
# Judul
# Siaran Pers YLKI : Mendesak PT Pertamina untuk ...                                           0.517441
# Pertamina Kembangkan Program Non-Tunai Pembelia...                                           0.476020
# Pertamina Tak Masalahkan Nama Pertamini, tapi...                                             0.344119
# Pertamina Patra Niaga Akan Bangun SPBU Skala UK...                                           0.587346
# Gaji Manajer 'Engineering' Chevron Rp 51,25 Jut...                                           0.266363
#
# [5 rows x 50 columns]
# Most similar documents to 'Siaran Pers YLKI : Mendesak PT Pertamina untuk Perketat Pengawasan SPBU':
# Judul
# Siaran Pers YLKI : Mendesak PT Pertamina untuk Perketat Pengawasan SPBU                             1.000000
# BBM Langka di Medan, Ombudsman Sebut Mitigasi Pertamina Buruk                                       0.608881
# Hadirkan Energi ke Pelosok Negeri, Pertamina Patra Niaga Berkomitmen Tambah Titik BBM Satu Harga    0.593879
# Pertamina Dorong Pengembangan Energi Terbarukan melalui Program Energi Berdikari                    0.558962
# Pertamina Jamin Stok BBM Jelang Mudik 2017                                                          0.557734
# Pertamina MOR III Raih Patra Nirbaya Karya Pratama                                                  0.556797
# Name: Siaran Pers YLKI : Mendesak PT Pertamina untuk Perketat Pengawasan SPBU, dtype: float32

# %%
# --- 1. Install dependencies (if needed) ---
# pip install sentence-transformers scikit-learn matplotlib seaborn

# --- BLOK PEREDAM LOG & PROGRESS BAR ---
import os
import warnings
import transformers

# Mematikan progress bar download dari Hugging Face Hub
os.environ['HF_HUB_DISABLE_PROGRESS_BARS'] = '1'
# Menyembunyikan pesan peringatan/warnings
warnings.filterwarnings("ignore")
# Mematikan log dan progress bar loading dari library Transformers
transformers.logging.set_verbosity_error()
transformers.logging.disable_progress_bar()
# ---------------------------------------

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.cluster import KMeans

# --- 2. Load pertamina dataset ---
# assuming df['Konten'] already exists
sentences = df['Konten'].dropna().tolist()

# --- 3. Generate embeddings ---
model = SentenceTransformer('all-MiniLM-L6-v2')
embeddings = model.encode(sentences)

print("Embeddings shape:", embeddings.shape)
# Example: (N_sentences, 384)

# --- 4. Cosine Similarity Heatmap ---
cos_sim = cosine_similarity(embeddings)

plt.figure(figsize=(8,6))
sns.heatmap(cos_sim, cmap="viridis")
plt.title("Cosine Similarity Heatmap (pertamina Sentences)")
plt.show()

# --- 5. PCA Visualization ---
pca = PCA(n_components=2)
pca_result = pca.fit_transform(embeddings)

plt.figure(figsize=(8,6))
plt.scatter(pca_result[:,0], pca_result[:,1], alpha=0.7)
plt.title("PCA Visualization of Sentence Embeddings")
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.show()

# --- 6. t-SNE Visualization ---
tsne = TSNE(n_components=2, perplexity=30, random_state=42)
tsne_result = tsne.fit_transform(embeddings)

plt.figure(figsize=(8,6))
plt.scatter(tsne_result[:,0], tsne_result[:,1], alpha=0.7)
plt.title("t-SNE Visualization of Sentence Embeddings")
plt.show()

# --- 7. KMeans Clustering ---
kmeans = KMeans(n_clusters=3, random_state=42, n_init=10)
labels = kmeans.fit_predict(embeddings)

df['Cluster'] = labels  # add results back to DataFrame

# Visualize clusters with PCA
plt.figure(figsize=(8,6))
plt.scatter(pca_result[:,0], pca_result[:,1], c=labels, cmap="tab10", alpha=0.7)
plt.title("KMeans Clustering (PCA projection)")
plt.show()

# --- 8. Inspect cluster examples ---
for cluster_id in sorted(df['Cluster'].unique()):
    print(f"\nCluster {cluster_id} examples:")
    print(df[df['Cluster']==cluster_id]['Konten'].head(3).tolist())
# Out:
# Embeddings shape: (50, 384)
# Cluster 0 examples:
# ['PONTIANAK, KOMPAS.com - PT Pertamina mensosialisasikan program penggunaan uang elektronik untuk transaksi pembelian bahan bakar di setiap SPBU yang ada di seluruh kota Pontianak, Kalimantan Barat, Rabu (5/7/2017). Sosialisasi tersebut dihadiri sejumlah lembaga perbankan yang bekerjasama dengan Pertamina dalam program cashless tersebut. Sales Eksekutif BBM Pertamina Pontianak, Arwin Nugraha mengatakan, rencananya seluruh SPBU yang ada di Pontianak mulai tanggal 1 Januari 2018, untuk pembelian BBM sudah harus menggunakan uang elektronik (non tunai) ini. "Saat ini kita bekerja sama dengan Bank Indonesia maupun Hiswana Migas untuk mempersiapkan sarana dan prasarana pendukung, serta mengkampanyekan kepada masyarakat untuk menggunakan uang elektronik," ujar Arwin usai Kick Off SPBU Cashless di Hotel Grand Tulip, Rabu (5/7/2017). Saat ini, ungkap Arwin, sejumlah bank yang sebelumnya sudah mempunyai program uang elektronik seperti BCA, BRI, Mandiri atau bank lainnya. "Tapi yang saat ini untuk tahap awal sosialisasi yang paling siap dalam program ini adalah bank BCA dengan program Flazz dan BRI dengan program Brizzi nya," papar Arwin.\n\nSaat ini, seluruh SPBU yang ada di Pontianak sudah memiliki EDC (Electronic Data Captures) yang akan digunakan Pertamina dalam menyebarkan uang elektronik kepada pelanggan. Uang elektronik di SPBU ini akan mulai diberlakukan setiap hari Sabtu dan Minggu pada bulan Juli  di satu jalur premium yabg dikhususkan untuk pengguna uang elektronik dan konsumen tetap bisa membeli bahan bakar lainnya dengan seperti biasa. Pimpinan BCA KCU Pontianak, Hartoyo mengatakan saat ini pihaknya bersama Bank Kalbar melakukan co-branding dengan Flazz, yang diharapkan bisa menjadi tahap awal dalam mensukseskan program uang elektronik ini. "Jadi sistem yang digunakan adalah sistem top up (isi ulang). Nasabah, cukup memiliki satu kartu di awal yang bisa diisi ulang untuk transaksi pembelian BBM di SPBU," ujar Hartoyo. Untuk meminimalisir resiko, jelas Hartoyo, setiap nasabah akan dibatasi untuk setiap pengisian ulang maksimal sebesar Rp 1.000.000. Karena kartu ini bisa digunakan oleh siapa saja, sehingga apabila tercecer atau hilang, masih bisa digunakan oleh orang yang menemukan nya. "Jadi sebenarnya sama saja, jika kehilangan atau tercecer uang tunai, ya sudah jadi pemilik yang menemukannya. Untuk itu, kita batasi maksimal Rp.1.000.000 untuk meminimalisir resiko tersebut yang masih bisa ditolerir oleh masyarakat," ujarnya. Ketua Hiswana Migas Kalbar, Hendra Salam menjelaskan, ada tiga hal yang menjadi benefit dengan menggunakan transaksi uang elektronik tersebut. Salah satunya adalah faktor keamanan, karena dengan uang elektronik, setiap transaksi pembelian akan langsung masuk ke rekening. "Karena kalau pakai uang tunai, ada
kmeans = KMeans(n_clusters=3, random_state=42, n_init=10)
labels = kmeans.fit_predict(embeddings)

df['Cluster'] = labels  # add results back to DataFrame

# --- 8. Heuristic Cluster Labeling ---
# Define simple keyword sets (you can adjust based on your pertamina dataset)
keywords_map = {
    "Challenge": ["masalah", "tantangan", "hambatan", "kesulitan", "kurang", "gagal"],
    "Solution": ["solusi", "program", "inisiatif", "kebijakan", "strategi", "dukungan"],
    "Impact": ["ekonomi", "dampak", "manfaat", "pengaruh", "hasil", "perubahan"]
}

cluster_labels = {}

for cluster_id in sorted(df['Cluster'].unique()):
    cluster_texts = " ".join(df[df['Cluster']==cluster_id]['Konten'].tolist()).lower()

    scores = {label: sum(word in cluster_texts for word in words)
              for label, words in keywords_map.items()}

    best_label = max(scores, key=scores.get) if any(scores.values()) else "Other"
    cluster_labels[cluster_id] = best_label

# Map cluster numbers → descriptive labels
df['Cluster_Label'] = df['Cluster'].map(cluster_labels)

# --- 9. Inspect cluster examples ---
for cluster_id, label in cluster_labels.items():
    print(f"\nCluster {cluster_id} → {label}")
    print(df[df['Cluster']==cluster_id]['Konten'].head(3).tolist())

# --- 10. Visualize with descriptive labels ---
plt.figure(figsize=(8,6))
for cluster_id, label in cluster_labels.items():
    mask = df['Cluster'] == cluster_id
    plt.scatter(pca_result[mask,0], pca_result[mask,1], label=label, alpha=0.7)

plt.title("KMeans Clustering (PCA projection with Labels)")
plt.legend()
plt.show()
# Out:
# Cluster 0 → Challenge
# ['PONTIANAK, KOMPAS.com - PT Pertamina mensosialisasikan program penggunaan uang elektronik untuk transaksi pembelian bahan bakar di setiap SPBU yang ada di seluruh kota Pontianak, Kalimantan Barat, Rabu (5/7/2017). Sosialisasi tersebut dihadiri sejumlah lembaga perbankan yang bekerjasama dengan Pertamina dalam program cashless tersebut. Sales Eksekutif BBM Pertamina Pontianak, Arwin Nugraha mengatakan, rencananya seluruh SPBU yang ada di Pontianak mulai tanggal 1 Januari 2018, untuk pembelian BBM sudah harus menggunakan uang elektronik (non tunai) ini. "Saat ini kita bekerja sama dengan Bank Indonesia maupun Hiswana Migas untuk mempersiapkan sarana dan prasarana pendukung, serta mengkampanyekan kepada masyarakat untuk menggunakan uang elektronik," ujar Arwin usai Kick Off SPBU Cashless di Hotel Grand Tulip, Rabu (5/7/2017). Saat ini, ungkap Arwin, sejumlah bank yang sebelumnya sudah mempunyai program uang elektronik seperti BCA, BRI, Mandiri atau bank lainnya. "Tapi yang saat ini untuk tahap awal sosialisasi yang paling siap dalam program ini adalah bank BCA dengan program Flazz dan BRI dengan program Brizzi nya," papar Arwin.\n\nSaat ini, seluruh SPBU yang ada di Pontianak sudah memiliki EDC (Electronic Data Captures) yang akan digunakan Pertamina dalam menyebarkan uang elektronik kepada pelanggan. Uang elektronik di SPBU ini akan mulai diberlakukan setiap hari Sabtu dan Minggu p
an Medan Belawan, Kamis (4/12/2025).\r\n\r\nLokasi pertama yang disambangi adalah terminal penyimpanan pasokan BBM jenis Pertamina Dex dan industri. Kemudian rombongan juga melakukan inspeksi ke Fuel Terminal Medan Group.\r\n\r\nDari lokasi pertama, Ombudsman menemukan pasokan untuk Pertamina Dex tersedia. Pasokannya juga cukup untuk menyuplai SPBU di Kota Medan. Begitu juga di lokasi kedua. Pasokan diklaim sudah cukup memasok untuk SPBU di Kota Medan.\r\n\r\nSebelumnya, menurut klaim Pertamina, kelangkaan BBM terjadi karena kapal pemasok BBM tidak bisa sandar ke lokasi pengisian terminal dikarenakan cuaca buruk. Kapal itu baru bisa bersandar pada 29 November 2025.\r\n\r\nMeski proses distribusi BBM sudah mulai normal, Ombudsman tetap memberikan sejumlah catatan penting terkait pelayanan publik.\n\n1. Temuan Ombudsman, perbaikan tangki hingga distribusi yang terkendala\nDalam sidak itu, Ombudsman menemukan beberapa fakta yang menjadi catatan mereka. Dari lokasi terminal BBM, Ombudsman menemukan ada perbaikan lima tangki penyimpanan stok BBM. Kondisi ini membuat, kapasitas penampungan di terminal belum bisa dimaksimalkan. Dari 135 ribu Kiloliter, saat ini hanya bisa menampung 90 ribu Kiloliter.\n\nMenurut Anggota Ombudsman RI, Jemsly Hutabarat, kondisi ini juga berpengaruh pada keandalan pasokan BBM. Apalagi saat kondisi kahar yang terjadi saat ini di Sumatera Utara.\r\n\r\nKemudian, Jemsly juga menyoroti soal proses distribusi. Harusnya, ketika kapal sudah san ...

# %%
# --- BLOK PEREDAM LOG & PROGRESS BAR ---
import os
import warnings
import transformers

# Mematikan progress bar download dari Hugging Face Hub
os.environ['HF_HUB_DISABLE_PROGRESS_BARS'] = '1'
# Menyembunyikan pesan peringatan/warnings
warnings.filterwarnings("ignore")
# Mematikan log dan progress bar loading dari library Transformers
transformers.logging.set_verbosity_error()
transformers.logging.disable_progress_bar()
# ---------------------------------------

from sentence_transformers import SentenceTransformer
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# --- 1. Ambil beberapa contoh kalimat (supaya plot tidak terlalu padat) ---
sample_sentences = df['Konten'].dropna().sample(20, random_state=42).tolist()

# --- 2. Buat embeddings ---
model = SentenceTransformer('all-MiniLM-L6-v2')
embeddings = model.encode(sample_sentences)

# --- 3. Reduksi dimensi ke 2D (PCA) ---
pca = PCA(n_components=2)
X_2d = pca.fit_transform(embeddings)

# --- 4. Plot ---
plt.figure(figsize=(8,6))
plt.scatter(X_2d[:,0], X_2d[:,1], c="blue", alpha=0.7)

for i, text in enumerate(sample_sentences):
    plt.text(X_2d[i,0]+0.02, X_2d[i,1]+0.02, text[:30]+"...", fontsize=8)

plt.title("Visualisasi Kalimat (Embeddings → PCA 2D)")
plt.xlabel("Dimensi 1")
plt.ylabel("Dimensi 2")
plt.grid(True)
plt.show()

# %%
# --- BLOK PEREDAM LOG & PROGRESS BAR ---
import os
import warnings
import transformers

os.environ['HF_HUB_DISABLE_PROGRESS_BARS'] = '1'
warnings.filterwarnings("ignore")
transformers.logging.set_verbosity_error()
transformers.logging.disable_progress_bar()
# ---------------------------------------

from sentence_transformers import SentenceTransformer
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

sentences = [
    "Kecurangan takaran pada SPBU merugikan banyak konsumen.",
    "Penimbunan BBM bersubsidi adalah tindakan melanggar hukum.",
    "PT Pertamina berkomitmen menjaga pasokan energi nasional.",
    "Pemerintah terus mendorong distribusi BBM tepat sasaran.",
    "Fluktuasi harga minyak dunia memengaruhi harga BBM non-subsidi."
]

model = SentenceTransformer('all-MiniLM-L6-v2')
embeddings = model.encode(sentences)

pca = PCA(n_components=2)
X_2d = pca.fit_transform(embeddings)

plt.figure(figsize=(8,6)) # Sedikit diperbesar agar teks lebih rapi
plt.scatter(X_2d[:,0], X_2d[:,1], c="blue")

for i, text in enumerate(sentences):
    plt.text(X_2d[i,0]+0.02, X_2d[i,1]+0.02, text[:30]+"...", fontsize=9)

plt.title("Visualisasi Embeddings (Contoh Isu & Kebijakan Pertamina)")
plt.xlabel("Dimensi 1")
plt.ylabel("Dimensi 2")
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# --- 1. Contoh kalimat (konteks Pertamina) ---
sentences = [
    "Kecurangan takaran pada SPBU merugikan banyak konsumen.",
    "Penimbunan BBM bersubsidi adalah tindakan melanggar hukum.",
    "PT Pertamina berkomitmen menjaga pasokan energi nasional.",
    "Pemerintah terus mendorong distribusi BBM tepat sasaran.",
    "Fluktuasi harga minyak dunia memengaruhi harga BBM non-subsidi."
]

# --- 2. Buat dummy embeddings (random tapi stabil dengan seed) ---
np.random.seed(42)
embeddings = np.random.rand(len(sentences), 50)  # 50 dimensi dummy

# --- 3. Reduksi dimensi ke 2D (PCA) ---
pca = PCA(n_components=2)
X_2d = pca.fit_transform(embeddings)

# --- 4. Plot hasil ---
plt.figure(figsize=(8,6))
plt.scatter(X_2d[:,0], X_2d[:,1], c="blue", alpha=0.7)

for i, text in enumerate(sentences):
    plt.text(X_2d[i,0]+0.02, X_2d[i,1]+0.02, text[:35]+"...", fontsize=9)

plt.title("Dummy Visualisasi Embeddings (Konteks Pertamina)")
plt.xlabel("Dimensi 1")
plt.ylabel("Dimensi 2")
plt.grid(True)
plt.show()

# %%
# --- BLOK PEREDAM LOG & PROGRESS BAR ---
import os
import warnings
import transformers

os.environ['HF_HUB_DISABLE_PROGRESS_BARS'] = '1'
warnings.filterwarnings("ignore")
transformers.logging.set_verbosity_error()
transformers.logging.disable_progress_bar()
# ---------------------------------------

# --- 1. Install library jika belum ada ---
# pip install sentence-transformers scikit-learn matplotlib

from sentence_transformers import SentenceTransformer
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# --- 2. Contoh kalimat (konteks Pertamina) ---
sentences = [
    "Kecurangan takaran pada SPBU merugikan banyak konsumen.",
    "Penimbunan BBM bersubsidi adalah tindakan melanggar hukum.",
    "PT Pertamina berkomitmen menjaga pasokan energi nasional.",
    "Pemerintah terus mendorong distribusi BBM tepat sasaran.",
    "Fluktuasi harga minyak dunia memengaruhi harga BBM non-subsidi."
]

# --- 3. Buat embeddings dengan model Sentence-BERT ---
model = SentenceTransformer('all-MiniLM-L6-v2')
embeddings = model.encode(sentences)

print("Ukuran embeddings:", embeddings.shape)  # contoh: (5, 384)

# --- 4. Reduksi dimensi ke 2D (PCA) ---
pca = PCA(n_components=2)
X_2d = pca.fit_transform(embeddings)

# --- 5. Plot hasil visualisasi ---
plt.figure(figsize=(8,6))
plt.scatter(X_2d[:,0], X_2d[:,1], c="blue", alpha=0.7)

for i, text in enumerate(sentences):
    plt.text(X_2d[i,0]+0.02, X_2d[i,1]+0.02, text[:35]+"...", fontsize=9)

plt.title("Visualisasi Embeddings (Sentence-BERT Topik Pertamina)")
plt.xlabel("Dimensi 1")
plt.ylabel("Dimensi 2")
plt.grid(True)
plt.show()
# Out:
# Ukuran embeddings: (5, 384)
